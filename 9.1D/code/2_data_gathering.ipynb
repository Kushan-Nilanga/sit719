# %%
import IPython  
import utils
nb_path = IPython.extract_module_locals()[1]['__vsc_ipynb_file__']
nb_name = nb_path.split('/')[-1].split('.')[0]
artefacts_dir = utils.create_artifacts_dir('../artefacts/'+nb_name)

# %% [markdown]
# ## Loading CSV files

# %%
import pandas as pd
data_train = pd.read_csv('../data/trainingData.csv')
data_train.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
data_test = pd.read_csv('../data/validationData.csv')
data_test.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520    LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7515.916799  4.864890e+06      1           1        0
# 1     100  ...     100 -7383.867221  4.864840e+06      4           2        0
# 2     100  ...     100 -7374.302080  4.864847e+06      4           2        0
# 3     100  ...     100 -7365.824883  4.864843e+06      4           2        0
# 4     100  ...     100 -7641.499303  4.864922e+06      2           0        0
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
# saving to artefacts
data_train.to_csv(artefacts_dir+'/data_train.csv', index=False)
data_test.to_csv(artefacts_dir+'/data_test.csv', index=False)
